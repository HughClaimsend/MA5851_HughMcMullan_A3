# %% [markdown]
# <a href="https://colab.research.google.com/github/HughClaimsend/MA5851_HughMcMullan_A3/blob/main/MA5851_Hugh_McMullan_A3_Part3_Pre_processing_Posts_Text_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries needed for this notebook
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import re

import nltk
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer

from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# The data files are located on the Google Drive, so do a drive.mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read in the DronePosts.csv data, created in the Part 1 notebook
dfDronePostsSince2018 = pd.read_csv('/content/drive/MyDrive/DronePostsSince2018_202112041100.csv')
display(dfDronePostsSince2018)
# Out:
#       Unnamed: 0  ...                                          post_text
# 0              0  ...  ..\nLatest CASA newsletter has VLOS article wh...
# 1              1  ...  I'm guessing they're making a distinction betw...
# 2              2  ...  If it’s like the US, the expectation is to use...
# 3              3  ...  CASA is not trying to tell us to keep our eyes...
# 4              4  ...  \n\nthispilothere said:\n\n\n\nI'm guessing th...
# ...          ...  ...                                                ...
# 7663       12146  ...  Would anyone be interested in flying gently cu...
# 7664       12200  ...  \n\n\n\n\nCastel Beseno is an impressive fortr...
# 7665       12457  ...  \n\n\n\nAerial footage of one of Italy's hidde...
# 7666       12458  ...  As always, your video is stunning. As good as ...
# 7667       14842  ...  I have been using the quick release props with...
#
# [7668 rows x 6 columns]

# %%
dfPreppedText = dfDronePostsSince2018
dfPreppedText['target_text'] = dfPreppedText['thread_name'] + " " + dfPreppedText['post_text']
display(dfPreppedText)
# Out:
#       Unnamed: 0  ...                                        target_text
# 0              0  ...  Latest CASA newsletter re VLOS ..\nLatest CASA...
# 1              1  ...  Latest CASA newsletter re VLOS I'm guessing th...
# 2              2  ...  Latest CASA newsletter re VLOS If it’s like th...
# 3              3  ...  Latest CASA newsletter re VLOS CASA is not try...
# 4              4  ...  Latest CASA newsletter re VLOS \n\nthispilothe...
# ...          ...  ...                                                ...
# 7663       12146  ...  Litchi wapoint missions Would anyone be intere...
# 7664       12200  ...  Beseno Castle in 6K \n\n\n\n\nCastel Beseno is...
# 7665       12457  ...  Val Formazza Mountains and a stunning Waterfal...
# 7666       12458  ...  Val Formazza Mountains and a stunning Waterfal...
# 7667       14842  ...  Avoid non-DJI 1345S Quick Release Prop Mounts ...
#
# [7668 rows x 7 columns]

# %%
dfPreppedText
# Out:
#       Unnamed: 0  dronesite_group  ...  post_text  target_text
# 0          False            False  ...      False        False
# 1          False            False  ...      False        False
# 2          False            False  ...      False        False
# 3          False            False  ...      False        False
# 4          False            False  ...      False        False
# ...          ...              ...  ...        ...          ...
# 7663       False            False  ...      False        False
# 7664       False            False  ...      False        False
# 7665       False            False  ...      False        False
# 7666       False            False  ...      False        False
# 7667       False            False  ...      False        False
#
# [7668 rows x 7 columns]

# %% [markdown]
# Drop any rows with null values

# %%
dfPreppedText = dfPreppedText.dropna()
dfPreppedText
# Out:
#       Unnamed: 0  ...                                        target_text
# 0              0  ...  Latest CASA newsletter re VLOS ..\nLatest CASA...
# 1              1  ...  Latest CASA newsletter re VLOS I'm guessing th...
# 2              2  ...  Latest CASA newsletter re VLOS If it’s like th...
# 3              3  ...  Latest CASA newsletter re VLOS CASA is not try...
# 4              4  ...  Latest CASA newsletter re VLOS \n\nthispilothe...
# ...          ...  ...                                                ...
# 7663       12146  ...  Litchi wapoint missions Would anyone be intere...
# 7664       12200  ...  Beseno Castle in 6K \n\n\n\n\nCastel Beseno is...
# 7665       12457  ...  Val Formazza Mountains and a stunning Waterfal...
# 7666       12458  ...  Val Formazza Mountains and a stunning Waterfal...
# 7667       14842  ...  Avoid non-DJI 1345S Quick Release Prop Mounts ...
#
# [7667 rows x 7 columns]

# %%
dfPreppedText.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7667 entries, 0 to 7667
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       7667 non-null   int64
#  1   dronesite_group  7667 non-null   object
#  2   thread_name      7667 non-null   object
#  3   post_YYMM        7667 non-null   int64
#  4   post_YYYY        7667 non-null   int64
#  5   post_text        7667 non-null   object
#  6   target_text      7667 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 479.2+ KB

# %%
# NLTK constants
PATTERN_S = re.compile("\'s")           # matches `'s` from text
PATTERN_R = re.compile("\r")            #matches `\r`
PATTERN_N = re.compile("\n")            #matches `\r` and `\n`
PATTERN_PUNC = re.compile(r"[^\w\s]")   # matches all non 0-9 A-z whitespace
STOPWORDS = set(stopwords.words('english'))

# %%
# function for text cleaning 
def clean_text_using_nltk(text):
    text = text.lower()                     # Convert text to lowercase 

    text = re.sub(PATTERN_S, ' ', text)     # Remove apostrophe-s
    text = re.sub(PATTERN_R, ' ', text)     # Remove escaped \r characters
    text = re.sub(PATTERN_N, ' ', text)     # Remove escaped \n characters
    text = re.sub(PATTERN_PUNC, ' ', text)  # Remove non 0-9 A-z whitespace
    
    return text

# Apply the text cleaning function to the target_text
dfPreppedText['cleaned_text'] = dfPreppedText['target_text'].apply(lambda s: clean_text_using_nltk(s))
display(dfPreppedText)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#       Unnamed: 0  ...                                       cleaned_text
# 0              0  ...  latest casa newsletter re vlos    latest casa ...
# 1              1  ...  latest casa newsletter re vlos i m guessing th...
# 2              2  ...  latest casa newsletter re vlos if it s like th...
# 3              3  ...  latest casa newsletter re vlos casa is not try...
# 4              4  ...  latest casa newsletter re vlos   thispilothere...
# ...          ...  ...                                                ...
# 7663       12146  ...  litchi wapoint missions would anyone be intere...
# 7664       12200  ...  beseno castle in 6k      castel beseno is an i...
# 7665       12457  ...  val formazza mountains and a stunning waterfal...
# 7666       12458  ...  val formazza mountains and a stunning waterfal...
# 7667       14842  ...  avoid non dji 1345s quick release prop mounts ...
#
# [7667 rows x 8 columns]

# %%
# function to remove stopwords
def remove_stopwords(text):
    no_stopword_text = [w for w in text.split() if not w in STOPWORDS]
    return ' '.join(no_stopword_text)

# Apply the stopwords removal function to the corpus text
dfPreppedText['cleaned_text'] = dfPreppedText['cleaned_text'].apply(lambda s: remove_stopwords(s))
display(dfPreppedText)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#       Unnamed: 0  ...                                       cleaned_text
# 0              0  ...  latest casa newsletter vlos latest casa newsle...
# 1              1  ...  latest casa newsletter vlos guessing making di...
# 2              2  ...  latest casa newsletter vlos like us expectatio...
# 3              3  ...  latest casa newsletter vlos casa trying tell u...
# 4              4  ...  latest casa newsletter vlos thispilothere said...
# ...          ...  ...                                                ...
# 7663       12146  ...  litchi wapoint missions would anyone intereste...
# 7664       12200  ...  beseno castle 6k castel beseno impressive fort...
# 7665       12457  ...  val formazza mountains stunning waterfall cine...
# 7666       12458  ...  val formazza mountains stunning waterfall cine...
# 7667       14842  ...  avoid non dji 1345s quick release prop mounts ...
#
# [7667 rows x 8 columns]

# %%
# function to tokenize text
def apply_tokenizer(text):
    tokenizer = RegexpTokenizer('[a-zA-Z]\w+\'?\w*')    # use NLTK Regexp tokenizer
    return tokenizer.tokenize(text)

# Apply the stopwords removal function to the corpus text
dfPreppedText['tokenized_text'] = dfPreppedText['cleaned_text'].apply(lambda s: apply_tokenizer(s))
display(dfPreppedText)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#       Unnamed: 0  ...                                     tokenized_text
# 0              0  ...  [latest, casa, newsletter, vlos, latest, casa,...
# 1              1  ...  [latest, casa, newsletter, vlos, guessing, mak...
# 2              2  ...  [latest, casa, newsletter, vlos, like, us, exp...
# 3              3  ...  [latest, casa, newsletter, vlos, casa, trying,...
# 4              4  ...  [latest, casa, newsletter, vlos, thispilothere...
# ...          ...  ...                                                ...
# 7663       12146  ...  [litchi, wapoint, missions, would, anyone, int...
# 7664       12200  ...  [beseno, castle, castel, beseno, impressive, f...
# 7665       12457  ...  [val, formazza, mountains, stunning, waterfall...
# 7666       12458  ...  [val, formazza, mountains, stunning, waterfall...
# 7667       14842  ...  [avoid, non, dji, quick, release, prop, mounts...
#
# [7667 rows x 9 columns]

# %% [markdown]
# Confirm all rows have values

# %%
display(dfPreppedText.dropna())
# Out:
#       Unnamed: 0  ...                                     tokenized_text
# 0              0  ...  [latest, casa, newsletter, vlos, latest, casa,...
# 1              1  ...  [latest, casa, newsletter, vlos, guessing, mak...
# 2              2  ...  [latest, casa, newsletter, vlos, like, us, exp...
# 3              3  ...  [latest, casa, newsletter, vlos, casa, trying,...
# 4              4  ...  [latest, casa, newsletter, vlos, thispilothere...
# ...          ...  ...                                                ...
# 7663       12146  ...  [litchi, wapoint, missions, would, anyone, int...
# 7664       12200  ...  [beseno, castle, castel, beseno, impressive, f...
# 7665       12457  ...  [val, formazza, mountains, stunning, waterfall...
# 7666       12458  ...  [val, formazza, mountains, stunning, waterfall...
# 7667       14842  ...  [avoid, non, dji, quick, release, prop, mounts...
#
# [7667 rows x 9 columns]

# %%
dfPreppedText.to_csv('/content/drive/MyDrive/DronePostsPreppedText__202112041100.csv')

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS - DATA READY FOR NLP**

# %%
# Separate COMMERCIAL corpus from dfPreppedText
dfCommercial = dfPreppedText[dfPreppedText["dronesite_group"]=="Commercial"]
dfCommercial
# Out:
#       Unnamed: 0  ...                                     tokenized_text
# 5052        5953  ...  [process, reoc, hi, guys, im, new, enrolled, r...
# 5053        5954  ...  [process, reoc, stevechan, said, hi, guys, im,...
# 5054        5955  ...  [process, reoc, given, international, forum, m...
# 5055        5956  ...  [process, reoc, mate, documents, use, casa, we...
# 5056        5957  ...  [process, reoc, hi, guys, im, new, enrolled, r...
# ...          ...  ...                                                ...
# 7663       12146  ...  [litchi, wapoint, missions, would, anyone, int...
# 7664       12200  ...  [beseno, castle, castel, beseno, impressive, f...
# 7665       12457  ...  [val, formazza, mountains, stunning, waterfall...
# 7666       12458  ...  [val, formazza, mountains, stunning, waterfall...
# 7667       14842  ...  [avoid, non, dji, quick, release, prop, mounts...
#
# [2615 rows x 9 columns]

# %%
dfCommercial.to_csv('/content/drive/MyDrive/DronePostsCommercial_202112041100.csv')

# %%
# Separate PRIVATE corpus from dfPreppedText
dfPrivate = dfPreppedText[dfPreppedText["dronesite_group"]=="Private"]
dfPrivate
# Out:
#       Unnamed: 0  ...                                     tokenized_text
# 0              0  ...  [latest, casa, newsletter, vlos, latest, casa,...
# 1              1  ...  [latest, casa, newsletter, vlos, guessing, mak...
# 2              2  ...  [latest, casa, newsletter, vlos, like, us, exp...
# 3              3  ...  [latest, casa, newsletter, vlos, casa, trying,...
# 4              4  ...  [latest, casa, newsletter, vlos, thispilothere...
# ...          ...  ...                                                ...
# 5047        5926  ...  [question, casa, permit, fpv, drones, australi...
# 5048        5927  ...  [question, casa, permit, fpv, drones, australi...
# 5049        5939  ...  [question, casa, permit, fpv, drones, australi...
# 5050        5940  ...  [question, casa, permit, fpv, drones, australi...
# 5051        5941  ...  [question, casa, permit, fpv, drones, australi...
#
# [5052 rows x 9 columns]

# %%
dfPrivate.to_csv('/content/drive/MyDrive/DronePostsPrivate_202112041100.csv')

# %% [markdown]
# Show Top 20 words by frequency

# %%
def most_frequent_words(text, top_n):
  count_vec = CountVectorizer().fit(text)
  bag_of_words = count_vec.transform(text)
  word_count = bag_of_words.sum(axis = 0)
  word_freq = [(word, word_count[0, idx]) for word, idx in count_vec.vocabulary_.items()]
  word_freq = sorted(word_freq, key = lambda x: x[1], reverse=True)
  return word_freq[:top_n]

# %%
def convert_tuples_to_dictionary(tuples_list):
    dictionary = {}
    for a,b in tuples_list:
        dictionary[a] = b
    return dictionary

# %% [markdown]
# **Generate list and WordCloud for Top 20 Words in Commercial posts**

# %%
# Top 20 Words in Commercial posts
comm_top20_tuples = most_frequent_words([word for post in dfCommercial.tokenized_text for word in post], 20)
comm_top20_dictionary = convert_tuples_to_dictionary(comm_top20_tuples)
print(comm_top20_dictionary)

# WordCloud for Top 20 Words in Commercial posts
comm_top20_wordcloud = WordCloud(background_color="white", width=1000, height=1000, max_words=20, relative_scaling=0.5, normalize_plurals=False).generate_from_frequencies(comm_top20_dictionary)
plt.imshow(comm_top20_wordcloud)
# Out:
# {'casa': 2818, 'reoc': 2465, 'repl': 2256, 'good': 1403, 'drone': 1222, 'fly': 1108, 'said': 1081, 'expand': 1049, 'click': 1048, 'insurance': 969, 'would': 960, 'time': 794, 'pilots': 733, 'flying': 719, 'drones': 691, 'like': 655, 'get': 643, 'hello': 637, 'forum': 619, 'australia': 617}

# %%
# Top 20 Words in Commercial posts
priv_top20_tuples = most_frequent_words([word for post in dfPrivate.tokenized_text for word in post], 20)
priv_top20_dictionary = convert_tuples_to_dictionary(priv_top20_tuples)
print(priv_top20_dictionary)

# WordCloud for Top 20 Words in Commercial posts
priv_top20_wordcloud = WordCloud(background_color="white", width=1000, height=1000, max_words=20, relative_scaling=0.5, normalize_plurals=False).generate_from_frequencies(priv_top20_dictionary)
plt.imshow(priv_top20_wordcloud)
# Out:
# {'drone': 4980, 'fly': 3539, 'flying': 3293, 'said': 2831, 'casa': 2509, 'click': 2401, 'expand': 2368, 'would': 2182, 'people': 1752, 'rules': 1749, 'drones': 1601, 'like': 1495, 'get': 1421, 'see': 1317, 'know': 1250, 'one': 1211, 'flight': 1201, 'new': 1157, 'australia': 1149, 'aircraft': 1142}

# %%
betas = [0.010726608, 0.010416165, 0.008519183, 0.008314907, 0.008236382, 0.00818274]
words = ['time', 'drone', 'expand', 'said', 'footage', 'click']
zip_iterator = zip(words, betas)
a_dictionary = dict(zip_iterator)
a_dictionary
# Out:
# {'click': 0.00818274,
#  'drone': 0.010416165,
#  'expand': 0.008519183,
#  'footage': 0.008236382,
#  'said': 0.008314907,
#  'time': 0.010726608}
